# %% [markdown]
# #### No_Tashkeel

# %%
# !pip install py7zr
# !git clone https://github.com/mohataher/TextRecognitionDataGenerator.git
# !pip install git+https://github.com/mohataher/TextRecognitionDataGenerator.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 647.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.8/413.8 kB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 29.6 MB/s eta 0:00:00
# ...
# Cloning into 'TextRecognitionDataGenerator'...
# remote: Enumerating objects: 1585, done.
# remote: Total 1585 (delta 0), reused 0 (delta 0), pack-reused 1585
# Receiving objects: 100% (1585/1585), 157.02 MiB | 19.27 MiB/s, done.
# Resolving deltas: 100% (638/638), done.
# Updating files: 100% (633/633), done.
# ...
#   Cloning https://github.com/mohataher/TextRecognitionDataGenerator.git to /tmp/pip-req-build-ixudu6ja
# ...

# %%
from trdg.generators import (
    GeneratorFromStrings,
)

# %%
import numpy as np
import pandas as pd
import random
import os
from py7zr import SevenZipFile

# %%
your_name = 'malak'
your_folder = 'ImageAndText_dir'

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
csv_path = f'/content/gdrive/MyDrive/{your_folder}/OCR Project/Datasets/Batch to Generate/Generation_batches/no_tashkeel_{your_name}_batch.csv'

# %%
mybatch = pd.read_csv(f'{csv_path}')
mybatch
# Out:
#                                                      text  original_index
# 0                       الاستعلام الخاص بي لتحقيق النتيجة               8
# 1                                       مجموعة من الرسائل              11
# 2                            يصل إليه منطاد الهواء الساخن              23
# 3        المعادلة الكيميائية موزونة عندما يكون عدد الذرات              40
# 4                   التاريخية والحواجز اللغوية على الوصول              45
# ...                                                   ...             ...
# 149995  هل يمكنك توفير خوارزمية يمكنها العثور على عدد ...         4210215
# 149996                                       مجموعة معينة         4210216
# 149997                             ما هو الناقل البوليمري         4210218
# 149998                                       المصفوفة بغض         4210253
# 149999              (المعروف أيضًا باسم "ثراش") هو موسيقي         4210316
#
# [150000 rows x 2 columns]

# %%
generation_list = mybatch['text'].tolist()

# %%
len(generation_list)
# Out:
# 150000

# %%
baghdad_list = generation_list[0:52500]
rakkas_list = generation_list[52500:105000]
bahij_list = generation_list[105000:]

# %%
baghdad_generator = GeneratorFromStrings(baghdad_list,
                              count=len(baghdad_list),
                              size=75,
                              background_type=1,
                              fit=True,
                              fonts=['baghdad.ttf'],
                              rtl = True)

os.mkdir(f'{your_name}_generated_baghdad')
path = f"./{your_name}_generated_baghdad/{your_name}_no_tashkeel_baghdad"

for i, (img, lbl) in enumerate(baghdad_generator):
    image_info = img.info.copy()
    image_info['dpi'] = (300, 300)
    img_path = f"{path}_{i+1}.tif"
    txt_path = f"{path}_{i+1}.gt.txt"

    img.save(img_path, **image_info)
    with open(txt_path, 'w') as f:
        f.write(lbl)

    # Print statement to indicate saved files
    print(f"Saved image: {img_path}")
    print(f"Saved label: {txt_path}")

# %%
import shutil
shutil.rmtree('shaden_generated_rakkas')

# %%
rakkas_generator = GeneratorFromStrings(rakkas_list,
                              count=len(rakkas_list),
                              size=75,
                              background_type=1,
                              fit=True,
                              fonts=['rakkas.ttf'],
                              rtl = True)

os.mkdir(f'{your_name}_generated_rakkas')
path = f"./{your_name}_generated_rakkas/{your_name}_no_tashkeel_rakkas"

for i, (img, lbl) in enumerate(rakkas_generator):
    image_info = img.info.copy()
    image_info['dpi'] = (300, 300)
    img_path = f"{path}_{i+1}.tif"
    txt_path = f"{path}_{i+1}.gt.txt"

    img.save(img_path, **image_info)
    with open(txt_path, 'w') as f:
        f.write(lbl)

    # Print statement to indicate saved files
    print(f"Saved image: {img_path}")
    print(f"Saved label: {txt_path}")
# Out:
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_1.tif
# Saved label: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_1.gt.txt
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_2.tif
# Saved label: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_2.gt.txt
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_3.tif
# Saved label: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_3.gt.txt
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_4.tif
# Saved label: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_4.gt.txt
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_5.tif
# Saved label: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_5.gt.txt
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_6.tif
# Saved label: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_6.gt.txt
# Saved image: ./shaden_generated_rakkas/shaden_no_tashkeel_rakkas_7.tif
# ...

# %%
rakkas_list[425]
# Out:
# '```'

# %%
del rakkas_list[425]

# %%
rakkas_list[425]
# Out:
# 'في أمستردام، يلتقي الثلاثة برجل'

# %%
len(rakkas_list)
# Out:
# 52499

# %%
bahij_generator = GeneratorFromStrings(bahij_list,
                              count=len(bahij_list),
                              size=75,
                              background_type=1,
                              fit=True,
                              fonts=['bahij.ttf'],
                              rtl = True)

os.mkdir(f'{your_name}_generated_bahij')
path = f"./{your_name}_generated_bahij/{your_name}_no_tashkeel_bahij"
for i, (img, lbl) in enumerate(bahij_generator):
    image_info = img.info.copy()
    image_info['dpi'] = (300, 300)
    img_path = f"{path}_{i+1}.tif"
    txt_path = f"{path}_{i+1}.gt.txt"

    img.save(img_path, **image_info)
    with open(txt_path, 'w') as f:
        f.write(lbl)

    # Print statement to indicate saved files
    print(f"Saved image: {img_path}")
    print(f"Saved label: {txt_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved image: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42501.tif
# Saved label: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42501.gt.txt
# Saved image: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42502.tif
# Saved label: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42502.gt.txt
# Saved image: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42503.tif
# Saved label: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42503.gt.txt
# Saved image: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42504.tif
# Saved label: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42504.gt.txt
# Saved image: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42505.tif
# Saved label: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42505.gt.txt
# Saved image: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42506.tif
# Saved label: ./shaden_generated_bahij/shaden_no_tashkeel_bahij_42506.gt.txt
# ...

# %%
folder_to_compress = f"./{your_name}_generated_baghdad"
output_archive = f"./gdrive/MyDrive/{your_folder}/{your_name}_generated_baghdad.7z"

with SevenZipFile(output_archive, 'w') as archive:
        archive.writeall(folder_to_compress)

# %%
folder_to_compress = f"./{your_name}_generated_bahij"
output_archive = f"./gdrive/MyDrive/{your_folder}/{your_name}_generated_bahij.7z"

with SevenZipFile(output_archive, 'w') as archive:
        archive.writeall(folder_to_compress)

# %%
folder_to_compress = f"./{your_name}_generated_rakkas"
output_archive = f"./gdrive/MyDrive/{your_folder}/{your_name}_generated_rakkas.7z"

with SevenZipFile(output_archive, 'w') as archive:
        archive.writeall(folder_to_compress)

# %%
import shutil
dir_path = '/content/shaden_generated_rakkas'

shutil.rmtree(dir_path)

# %% [markdown]
# ###Tashkeel Generation

# %%
csv_path2 = f'/content/gdrive/MyDrive/{your_folder}/Generation_batches/tashkeel_{your_name}_batch.csv'

# %%
mybatch = pd.read_csv(f'{csv_path2}')
mybatch
# Out:
#                                            text_tashkeel  original_index
# 0                    عَلَى قَوَاعِدَ عِلْمِيَّةٍ بَحْتْ،         8397950
# 1            وَعَلِمَ النَّفْسُ جُزْءٌ مِنَ الْفَلَسَفَة         8397969
# 2      النَّفْس. يَقُول: إِنَّ وُجُودَهَا مَوْضُوعَ ح...         8398141
# 3                                         مَسْأَلَةٌ مَا         8398153
# 4                يُحَاوِلُ — فِي جَمِيعِ الْمِيَادِينِ —         8398182
# ...                                                  ...             ...
# 99995  الأَفْوَاهُ تُرَدِّدُهُ الْأَلْسَنَةُ وَالشِّف...        12595437
# 99996                             تَحْتَ حِمَايَتِهِمَا.        12595489
# 99997  شُعُورِي نَحْوَكْ. وَهَذَا الشُّعُورُ أَنْتِ ا...        12595520
# 99998                   أَيْضًا، وَسَتَكُونُ الْإِشَارَة        12595544
# 99999          أُورليَان؟ وَمَنْ كَانَ هَذَا الرَّجُلُ —        12595610
#
# [100000 rows x 2 columns]

# %%
generation_tashkeel_list = mybatch['text_tashkeel'].tolist()

# %%
len(generation_tashkeel_list)
# Out:
# 100000

# %%
baghdad_tashk_list = generation_tashkeel_list[0:35000]
rakkas_tashk_list = generation_tashkeel_list[35000:70000]
bahij_tashk_list = generation_tashkeel_list[70000:]

# %%
import shutil
shutil.rmtree('malak_generated_tashkeel_baghdad')

# %%
baghdad_tashk_generator = GeneratorFromStrings(baghdad_tashk_list,
                              count=len(baghdad_tashk_list),
                              size=75,
                              background_type=1,
                              fit=True,
                              fonts=['baghdad.ttf'],
                              rtl = True)

os.mkdir(f'{your_name}_generated_tashkeel_baghdad')
path = f"./{your_name}_generated_tashkeel_baghdad/{your_name}_tashkeel_baghdad"

for i, (img, lbl) in enumerate(baghdad_tashk_generator):
    image_info = img.info.copy()
    image_info['dpi'] = (300, 300)
    img_path = f"{path}_{i+1}.tif"
    txt_path = f"{path}_{i+1}.gt.txt"

    img.save(img_path, **image_info)
    with open(txt_path, 'w') as f:
        f.write(lbl)

    print(f"Saved image: {img_path}")
    print(f"Saved label: {txt_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved image: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12109.tif
# Saved label: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12109.gt.txt
# Saved image: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12110.tif
# Saved label: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12110.gt.txt
# Saved image: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12111.tif
# Saved label: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12111.gt.txt
# Saved image: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12112.tif
# Saved label: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12112.gt.txt
# Saved image: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12113.tif
# Saved label: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12113.gt.txt
# Saved image: ./malak_generated_tashkeel_baghdad/malak_tashkeel_baghdad_12114.tif
# ...

# %%
folder_to_compress = f"./{your_name}_generated_tashkeel_baghdad"
output_archive = f"./gdrive/MyDrive/{your_folder}/{your_name}_generated_tashkeel_baghdad.7z"

with SevenZipFile(output_archive, 'w') as archive:
        archive.writeall(folder_to_compress)

# %%
rakkas_tashk_generator = GeneratorFromStrings(rakkas_tashk_list,
                              count=len(rakkas_tashk_list),
                              size=75,
                              background_type=1,
                              fit=True,
                              fonts=['rakkas.ttf'],
                              rtl = True)

os.mkdir(f'{your_name}_generated_tashkeel_rakkas')
path = f"./{your_name}_generated_tashkeel_rakkas/{your_name}_tashkeel_rakkas"

for i, (img, lbl) in enumerate(rakkas_tashk_generator):
    image_info = img.info.copy()
    image_info['dpi'] = (300, 300)
    img_path = f"{path}_{i+1}.tif"
    txt_path = f"{path}_{i+1}.gt.txt"

    img.save(img_path, **image_info)
    with open(txt_path, 'w') as f:
        f.write(lbl)

    print(f"Saved image: {img_path}")
    print(f"Saved label: {txt_path}")

# %%
folder_to_compress = f"./{your_name}_generated_tashkeel_rakkas"
output_archive = f"./gdrive/MyDrive/{your_folder}/{your_name}_generated_tashkeel_rakkas.7z"

with SevenZipFile(output_archive, 'w') as archive:
        archive.writeall(folder_to_compress)

# %%
bahij_tashk_generator = GeneratorFromStrings(bahij_tashk_list,
                              count=len(bahij_tashk_list),
                              size=75,
                              background_type=1,
                              fit=True,
                              fonts=['bahij.ttf'],
                              rtl = True)

os.mkdir(f'{your_name}_generated_tashkeel_bahij')
path = f"./{your_name}_generated_tashkeel_bahij/{your_name}_tashkeel_bahij"
for i, (img, lbl) in enumerate(bahij_generator):
    image_info = img.info.copy()
    image_info['dpi'] = (300, 300)
    img_path = f"{path}_{i+1}.tif"
    txt_path = f"{path}_{i+1}.gt.txt"

    img.save(img_path, **image_info)
    with open(txt_path, 'w') as f:
        f.write(lbl)

    print(f"Saved image: {img_path}")
    print(f"Saved label: {txt_path}")

# %%
folder_to_compress = f"./{your_name}_generated_tashkeel_bahij"
output_archive = f"./gdrive/MyDrive/{your_folder}/{your_name}_generated_tashkeel_bahij.7z"

with SevenZipFile(output_archive, 'w') as archive:
        archive.writeall(folder_to_compress)
