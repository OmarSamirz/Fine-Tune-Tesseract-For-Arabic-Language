# %% [markdown]
# ####Merging Datasets

# %%
import re
import string
import numpy as np
import pandas as pd
# from py7zr import SevenZipFile
# from pylibtashkeel import tashkeel
# from pyarabic.araby import strip_tashkeel, strip_tatweel

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
csv_path1 = '/OCR_ML/OCR Project/Datasets/Batches With Tashkeel/tashkeel_Omar_batch_7.csv'
csv_path2 = '/OCR_ML/OCR Project/Datasets/Batches With Tashkeel/tashkeel_Ibrahim_batch_6.csv'
csv_path3 = '/OCR_ML/OCR Project/Datasets/Batches With Tashkeel/tashkeel_youssef_batch_8_1.csv'
csv_path4 = '/OCR_ML/OCR Project/Datasets/Batches With Tashkeel/tashkeel_Gohary_batch_5.csv'

# %%
df1 = pd.read_csv(f'./gdrive/MyDrive{csv_path1}')
df2 = pd.read_csv(f'./gdrive/MyDrive{csv_path2}')
df3 = pd.read_csv(f'./gdrive/MyDrive{csv_path3}')
df4 = pd.read_csv(f'./gdrive/MyDrive{csv_path4}')

# %%
dataframes = [df1, df2, df3, df4]

# %%
merged_df = pd.concat(dataframes, ignore_index=True)
merged_df
# Out:
#                                                        text  \
# 0                                                  لدي جدول
# 1                                        يسمى "رسالة" يحتوي
# 2                             أريد عرض المحادثات الأخيرة مع
# 3                    عرض الرسالة الأخيرة. تتكون المحادثة من
# 4         بالحصول على مجموعتين منفصلتين - واحدة للرسائل ...
# ...                                                     ...
# 16804423                                            عن وباء
# 16804424                                  مع حلول شهر رمضان
# 16804425                                           المبارك.
# 16804426               فيديو إباحي يهدد حياة نيمار العاطفية
# 16804427                   إدانة أستاذ افتض بكارة تلميذته ب
#
#                                               text_tashkeel  num_tashkeel  \
# 0                                            لَدَي جَدْوَلْ             0
# 1                            يُسَمَّى "رِسَالَةً" يَحْتَوِي             0
# ...

# %%
merged_df.reset_index()
merged_df
# Out:
#                                                        text  \
# 0                                                  لدي جدول
# 1                                        يسمى "رسالة" يحتوي
# 2                             أريد عرض المحادثات الأخيرة مع
# 3                    عرض الرسالة الأخيرة. تتكون المحادثة من
# 4         بالحصول على مجموعتين منفصلتين - واحدة للرسائل ...
# ...                                                     ...
# 16804423                                            عن وباء
# 16804424                                  مع حلول شهر رمضان
# 16804425                                           المبارك.
# 16804426               فيديو إباحي يهدد حياة نيمار العاطفية
# 16804427                   إدانة أستاذ افتض بكارة تلميذته ب
#
#                                               text_tashkeel  num_tashkeel  \
# 0                                            لَدَي جَدْوَلْ             0
# 1                            يُسَمَّى "رِسَالَةً" يَحْتَوِي             0
# ...

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/one_mil_batch.csv"
merged_df.to_csv(file_name, encoding='utf-8-sig', index=False)

# %% [markdown]
# ####Reading & Splitting Merged Dataset

# %%
import numpy as np
import pandas as pd
import random

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
csv_path = '/OCR_ML/OCR Project/Datasets/Batch to Generate/one_mil_batch.csv'

# %%
whole_dataset = pd.read_csv(f'./gdrive/MyDrive{csv_path}')
whole_dataset
# Out:
#                                                        text  \
# 0                                                  لدي جدول
# 1                                        يسمى "رسالة" يحتوي
# 2                             أريد عرض المحادثات الأخيرة مع
# 3                    عرض الرسالة الأخيرة. تتكون المحادثة من
# 4         بالحصول على مجموعتين منفصلتين - واحدة للرسائل ...
# ...                                                     ...
# 16804423                                            عن وباء
# 16804424                                  مع حلول شهر رمضان
# 16804425                                           المبارك.
# 16804426               فيديو إباحي يهدد حياة نيمار العاطفية
# 16804427                   إدانة أستاذ افتض بكارة تلميذته ب
#
#                                               text_tashkeel  num_tashkeel  \
# 0                                            لَدَي جَدْوَلْ             0
# 1                            يُسَمَّى "رِسَالَةً" يَحْتَوِي             0
# ...

# %%
indices_list = whole_dataset.index.tolist()

# %%
len(indices_list)
# Out:
# 16804428

# %%
random.shuffle(indices_list)

# %%
one_million_indices = random.sample(indices_list, 1000000)
len(one_million_indices)
one_million_indices
# Out:
# [16398911,
#  14716042,
#  9895912,
#  8895426,
#  10046493,
#  9495398,
#  5345856,
#  10919060,
#  4774583,
#  12288312,
#  2582782,
#  4091094,
#  1385853,
#  2899227,
#  7686189,
#  2459936,
#  3478652,
#  5957787,
#  7580403,
#  2879666,
#  3319436,
#  7358742,
#  14439796,
#  14300618,
#  16115983,
#  15159074,
#  16630434,
#  7717799,
#  338738,
#  1754198,
#  12715371,
#  628065,
#  1320677,
#  8647165,
#  6365220,
#  15950242,
#  12394862,
#  16118036,
#  9994692,
#  7541407,
#  3398588,
#  2586030,
#  14078018,
#  3207277,
#  12699158,
#  9411767,
#  13207838,
#  3989524,
#  16563953,
#  2002397,
#  15382939,
#  6683312,
#  15775712,
#  4141433,
#  7227644,
#  7178185,
#  5016149,
#  13373985,
#  13998771,
#  6193652,
#  784935,
#  5443466,
#  9618487,
#  10010759,
#  4824709,
#  13039037,
#  15198428,
#  9042008,
#  6753526,
#  8934726,
#  7291627,
#  13719218,
#  16213653,
#  1905786,
#  13839056,
#  15935012,
#  3102665,
#  4829702,
#  1612388,
#  7771944,
#  10849343,
# ...

# %%
one_million_indices[-1]
# Out:
# 10531482

# %%
million_indices_array = np.array(one_million_indices)

# %%
np.save('./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Used Indices/one_mil_indices.npy', million_indices_array)

# %%
loaded_array = np.load('./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Used Indices/one_mil_indices.npy')
print(loaded_array)
# Out:
# [16398911 14716042  9895912 ...  3953013 11080247 10531482]

# %%
np.savetxt('./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Used Indices/one_mil_indices.csv', loaded_array, delimiter=',', fmt='%d')

# %%
no_tashkeel_list = one_million_indices[0:600000]
len(no_tashkeel_list)
# Out:
# 600000

# %%
tashkeel_list = one_million_indices[600000:1000000]
len(tashkeel_list)
# Out:
# 400000

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'indices_list' is your list of indices

# Create a DataFrame with indices from indices_list
indices1_df = pd.DataFrame(index=no_tashkeel_list)

# Filter the DataFrame to keep only the rows whose indices are in indices_list
no_tashkeel_df = whole_dataset[whole_dataset.index.isin(indices1_df.index)]
no_tashkeel_df
# Out:
#                                                        text  \
# 8                         الاستعلام الخاص بي لتحقيق النتيجة
# 11                                        مجموعة من الرسائل
# 23                             يصل إليه منطاد الهواء الساخن
# 40         المعادلة الكيميائية موزونة عندما يكون عدد الذرات
# 45                    التاريخية والحواجز اللغوية على الوصول
# ...                                                     ...
# 16804159  أبنائنا غير واردة ببرنامج مسار”، مضيفا: “بعد ا...
# 16804175          مع المؤسس والمدير العام لمواجهتهما بحقيقة
# 16804237                        لكرة القدم، على مواجهة نهضة
# 16804362                               مشاركة سياسية متدنية
# 16804404  على وقع التوتر الداخلي والتجاذبات بخصوص تجديد ...
#
#                                               text_tashkeel  num_tashkeel  \
# 8         الِاسْتِعْلَامُ الْخَاصُّ بِي لِتَحْقِيقِ النّ...             0
# 11                             مَجْمُوعَةٌ مِنَ الرَّسائِلِ             0
# ...

# %%
text_column = no_tashkeel_df['text']

# %%
no_tashkeel_text_df = pd.DataFrame(text_column, columns=['text'])
no_tashkeel_text_df
# Out:
#                                                        text
# 8                         الاستعلام الخاص بي لتحقيق النتيجة
# 11                                        مجموعة من الرسائل
# 23                             يصل إليه منطاد الهواء الساخن
# 40         المعادلة الكيميائية موزونة عندما يكون عدد الذرات
# 45                    التاريخية والحواجز اللغوية على الوصول
# ...                                                     ...
# 16804159  أبنائنا غير واردة ببرنامج مسار”، مضيفا: “بعد ا...
# 16804175          مع المؤسس والمدير العام لمواجهتهما بحقيقة
# 16804237                        لكرة القدم، على مواجهة نهضة
# 16804362                               مشاركة سياسية متدنية
# 16804404  على وقع التوتر الداخلي والتجاذبات بخصوص تجديد ...
#
# [600000 rows x 1 columns]

# %%
no_tashkeel_text_df['original_index'] = no_tashkeel_text_df.index
no_tashkeel_text_df
# Out:
#                                                        text  original_index
# 8                         الاستعلام الخاص بي لتحقيق النتيجة               8
# 11                                        مجموعة من الرسائل              11
# 23                             يصل إليه منطاد الهواء الساخن              23
# 40         المعادلة الكيميائية موزونة عندما يكون عدد الذرات              40
# 45                    التاريخية والحواجز اللغوية على الوصول              45
# ...                                                     ...             ...
# 16804159  أبنائنا غير واردة ببرنامج مسار”، مضيفا: “بعد ا...        16804159
# 16804175          مع المؤسس والمدير العام لمواجهتهما بحقيقة        16804175
# 16804237                        لكرة القدم، على مواجهة نهضة        16804237
# 16804362                               مشاركة سياسية متدنية        16804362
# 16804404  على وقع التوتر الداخلي والتجاذبات بخصوص تجديد ...        16804404
#
# [600000 rows x 2 columns]
# ...

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/no_tashkeel_batch.csv"
no_tashkeel_text_df.to_csv(file_name, encoding='utf-8-sig', index=False)

# %% [markdown]
# #### Dividing no tashkeel dataset

# %%
no_tashkeel_text_df_copy = no_tashkeel_text_df

# %%
no_tashkeel_text_df_copy.reset_index(drop=True, inplace=True)
no_tashkeel_text_df_copy
# Out:
#                                                      text  original_index
# 0                       الاستعلام الخاص بي لتحقيق النتيجة               8
# 1                                       مجموعة من الرسائل              11
# 2                            يصل إليه منطاد الهواء الساخن              23
# 3        المعادلة الكيميائية موزونة عندما يكون عدد الذرات              40
# 4                   التاريخية والحواجز اللغوية على الوصول              45
# ...                                                   ...             ...
# 599995  أبنائنا غير واردة ببرنامج مسار”، مضيفا: “بعد ا...        16804159
# 599996          مع المؤسس والمدير العام لمواجهتهما بحقيقة        16804175
# 599997                        لكرة القدم، على مواجهة نهضة        16804237
# 599998                               مشاركة سياسية متدنية        16804362
# 599999  على وقع التوتر الداخلي والتجاذبات بخصوص تجديد ...        16804404
#
# [600000 rows x 2 columns]

# %%
rows_per_dataframe = 150000

shaden = no_tashkeel_text_df_copy.iloc[:rows_per_dataframe]
mayar = no_tashkeel_text_df_copy.iloc[rows_per_dataframe:2*rows_per_dataframe]
malak = no_tashkeel_text_df_copy.iloc[2*rows_per_dataframe:3*rows_per_dataframe]
farida = no_tashkeel_text_df_copy.iloc[3*rows_per_dataframe:]

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/no_tashkeel_shaden_batch.csv"
shaden.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/no_tashkeel_mayar_batch.csv"
mayar.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/no_tashkeel_malak_batch.csv"
malak.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/no_tashkeel_farida_batch.csv"
farida.to_csv(file_name, encoding='utf-8-sig', index=False)

# %% [markdown]
# ####Tashkeel Dataset

# %%
indices2_df = pd.DataFrame(index=tashkeel_list)

tashkeel_df = whole_dataset[whole_dataset.index.isin(indices2_df.index)]
tashkeel_df
# Out:
#                                                    text  \
# 19                                           تطوير لعبة
# 30                                  هل تناول الشوكولاتة
# 104                يمكنني ضبط "قابل للترتيب" على "خطأ"؟
# 159                  قطع إحدى القطع المتبقية إلى أخماس،
# 233                  مع الأخذ في الاعتبار مجموعة متنوعة
# ...                                                 ...
# 16804364              الانتخابات العامة تشهد تعبئة جميع
# 16804379                              وخلافاً للتبريرات
# 16804391                   ملحوظاً، خصوصا بعد إعفائه من
# 16804406                                  شهور، والصراع
# 16804421  المقبل ، وذلك ابتداء من يوم الجمعة 24/04/2020
#
#                                               text_tashkeel  num_tashkeel  \
# 19                                        تَطْوِيرُ لُعْبَة             0
# 30                           هَلْ تَنَاوُلُ الشُّوكُولَاتَة             0
# ...

# %%
text_tashkeel_column = tashkeel_df['text_tashkeel']

# %%
text_tashkeel_df = pd.DataFrame(text_tashkeel_column, columns=['text_tashkeel'])
text_tashkeel_df
# Out:
#                                               text_tashkeel
# 19                                        تَطْوِيرُ لُعْبَة
# 30                           هَلْ تَنَاوُلُ الشُّوكُولَاتَة
# 104       يُمْكِنُنِي ضَبْطُ "قابِلْ لِلتَّرْتِيبِ" عَلَ...
# 159       قَطَعَ إِحْدَى الْقُطَعِ الْمُتَبَقِّيَةِ إِلَ...
# 233       مَعَ الْأَخْذِ فِي الاعْتِبَارِ مَجْمُوعَةٌ مُ...
# ...                                                     ...
# 16804364  الانْتِخابَاتُ الْعَامَّةُ تَشْهَدُ تَعْبِئَةٌ...
# 16804379                        وَخِلَافًا لِلتَّبْرِيرَاتِ
# 16804391       مَلْحُوظًا، خُصُوصًا بَعْدَ إِعْفَائِهِ مِنْ
# 16804406                               شُهُور، وَالصِّرَاعُ
# 16804421  الْمُقْبِلُ ، وَذَلِكَ ابْتِدَاءٌ مِنْ يَوْمِ ...
#
# [400000 rows x 1 columns]

# %%
text_tashkeel_df['original_index'] = text_tashkeel_df.index
text_tashkeel_df
# Out:
#                                               text_tashkeel  original_index
# 19                                        تَطْوِيرُ لُعْبَة              19
# 30                           هَلْ تَنَاوُلُ الشُّوكُولَاتَة              30
# 104       يُمْكِنُنِي ضَبْطُ "قابِلْ لِلتَّرْتِيبِ" عَلَ...             104
# 159       قَطَعَ إِحْدَى الْقُطَعِ الْمُتَبَقِّيَةِ إِلَ...             159
# 233       مَعَ الْأَخْذِ فِي الاعْتِبَارِ مَجْمُوعَةٌ مُ...             233
# ...                                                     ...             ...
# 16804364  الانْتِخابَاتُ الْعَامَّةُ تَشْهَدُ تَعْبِئَةٌ...        16804364
# 16804379                        وَخِلَافًا لِلتَّبْرِيرَاتِ        16804379
# 16804391       مَلْحُوظًا، خُصُوصًا بَعْدَ إِعْفَائِهِ مِنْ        16804391
# 16804406                               شُهُور، وَالصِّرَاعُ        16804406
# 16804421  الْمُقْبِلُ ، وَذَلِكَ ابْتِدَاءٌ مِنْ يَوْمِ ...        16804421
#
# [400000 rows x 2 columns]

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/text_tashkeel_batch.csv"
text_tashkeel_df.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
text_tashkeel_df.reset_index(drop=True, inplace=True)
text_tashkeel_df
# Out:
#                                             text_tashkeel  original_index
# 0                                       تَطْوِيرُ لُعْبَة              19
# 1                          هَلْ تَنَاوُلُ الشُّوكُولَاتَة              30
# 2       يُمْكِنُنِي ضَبْطُ "قابِلْ لِلتَّرْتِيبِ" عَلَ...             104
# 3       قَطَعَ إِحْدَى الْقُطَعِ الْمُتَبَقِّيَةِ إِلَ...             159
# 4       مَعَ الْأَخْذِ فِي الاعْتِبَارِ مَجْمُوعَةٌ مُ...             233
# ...                                                   ...             ...
# 399995  الانْتِخابَاتُ الْعَامَّةُ تَشْهَدُ تَعْبِئَةٌ...        16804364
# 399996                        وَخِلَافًا لِلتَّبْرِيرَاتِ        16804379
# 399997       مَلْحُوظًا، خُصُوصًا بَعْدَ إِعْفَائِهِ مِنْ        16804391
# 399998                               شُهُور، وَالصِّرَاعُ        16804406
# 399999  الْمُقْبِلُ ، وَذَلِكَ ابْتِدَاءٌ مِنْ يَوْمِ ...        16804421
#
# [400000 rows x 2 columns]

# %%
rows_per_dataframe = 100000

shaden2 = text_tashkeel_df.iloc[:rows_per_dataframe]
mayar2 = text_tashkeel_df.iloc[rows_per_dataframe:2*rows_per_dataframe]
malak2 = text_tashkeel_df.iloc[2*rows_per_dataframe:3*rows_per_dataframe]
farida2 = text_tashkeel_df.iloc[3*rows_per_dataframe:]

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/tashkeel_shaden_batch.csv"
shaden2.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/tashkeel_mayar_batch.csv"
mayar2.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/tashkeel_malak_batch.csv"
malak2.to_csv(file_name, encoding='utf-8-sig', index=False)

# %%
file_name = "./gdrive/MyDrive/OCR_ML/OCR Project/Datasets/Batch to Generate/tashkeel_farida_batch.csv"
farida2.to_csv(file_name, encoding='utf-8-sig', index=False)
